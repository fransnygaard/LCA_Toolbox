# %%
#!pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
with open("C:\\Users\\frans\\OneDrive\\Dev_OneDrive\\Rhino\\GH_LCA\\pytamiden\\index.html",encoding='utf8') as fp:
    soup = BeautifulSoup(fp, "html")

# %%
results = soup.find_all("div", class_="mat-overlay")
links =[]
for i in range(len(results)):
    links.append(results[i].attrs['data-link'])


print(links)
# Out:
# ['https://materialepyramiden.dk/?materialer=pandeplade', 'https://materialepyramiden.dk/?materialer=maling-mat', 'https://materialepyramiden.dk/?materialer=betontagsten', 'https://materialepyramiden.dk/?materialer=gulvparket', 'https://materialepyramiden.dk/?materialer=mdf', 'https://materialepyramiden.dk/?materialer=poroton-tegl', 'https://materialepyramiden.dk/?materialer=grantrae', 'https://materialepyramiden.dk/?materialer=egetrae', 'https://materialepyramiden.dk/?materialer=modificeret-trae', 'https://materialepyramiden.dk/?materialer=tegl-roed-dobbeltbraendt', 'https://materialepyramiden.dk/?materialer=tegl-roed-enkeltbraendt', 'https://materialepyramiden.dk/?materialer=beton-c20-25', 'https://materialepyramiden.dk/?materialer=aluvindue', 'https://materialepyramiden.dk/?materialer=traevindue', 'https://materialepyramiden.dk/?materialer=trae-alu-vindue', 'https://materialepyramiden.dk/?materialer=fibercement-plader-18-trae', 'https://materialepyramiden.dk/?materialer=kalkpuds-interioert', 'https://materialepyramiden.dk/?materialer=zink', 'https://materialepyramiden.dk/?materialer=vinyl-gulv-pvc', 'https://materialepyramiden.dk/?materialer=undertag', 'https://materialepyramiden.dk/?materialer=traefiberplade', 'https://materialepyramiden.dk/?materialer=teglsten-tag', 'https://materialepyramiden.dk/?materialer=tagpap', 'https://materialepyramiden.dk/?materialer=staal-galvaniseret', 'https://materialepyramiden.dk/?materialer=skifer', 'https://materialepyramiden.dk/?materialer=puds-eksterioert', 'https://materialepyramiden.dk/?materialer=gipsplade', 'https://materialepyramiden.dk/?materialer=linolieum', 'https://materialepyramiden.dk/?materialer=lerpuds', 'https://materialepyramiden.dk/?materialer=krydslamineret-trae-clt', 'https://materialepyramiden.dk/?materialer=kobber', 'https://materialepyramiden.dk/?materialer=klinker-stentoej', 'https://materialepyramiden.dk/?materialer=folier-pe', 'https://materialepyramiden.dk/?materialer=folier-epdm', 'https://materialepyramiden.dk/?materialer=fliser-keramik', 'https://materialepyramiden.dk/?materialer=fibercementplader', 'https://materialepyramiden.dk/?materialer=fermacell-gypsum-fibreboard', 'https://materialepyramiden.dk/?materialer=aluminum-plade', 'https://materialepyramiden.dk/?materialer=stenuld', 'https://materialepyramiden.dk/?materialer=pur', 'https://materialepyramiden.dk/?materialer=eps-skumplast-hvid', 'https://materialepyramiden.dk/?materialer=perlite-ekspanderet', 'https://materialepyramiden.dk/?materialer=pir', 'https://materialepyramiden.dk/?materialer=papiruld', 'https://materialepyramiden.dk/?materialer=hamp', 'https://materialepyramiden.dk/?materialer=glasuld', 'https://materialepyramiden.dk/?materialer=glasskum', 'https://materialepyramiden.dk/?materialer=window-glass-three-3-lags-glas', 'https://materialepyramiden.dk/?materialer=window-glass-single-1-lags-glas-2', 'https://materialepyramiden.dk/?materialer=plywood-krydsfiner', 'https://materialepyramiden.dk/?materialer=lerbaserede-mursten-braendte', 'https://materialepyramiden.dk/?materialer=kalksandsten', 'https://materialepyramiden.dk/?materialer=genbrugte-mursten-2', 'https://materialepyramiden.dk/?materialer=gasbeton-2', 'https://materialepyramiden.dk/?materialer=ceb-compressed-earth-brick-ubraendte-lersten', 'https://materialepyramiden.dk/?materialer=rammed-earth-stampede-lervaegge', 'https://materialepyramiden.dk/?materialer=structural-steel-konstruktionsstaal', 'https://materialepyramiden.dk/?materialer=limtrae', 'https://materialepyramiden.dk/?materialer=letbetonelementer', 'https://materialepyramiden.dk/?materialer=traefiberisolering', 'https://materialepyramiden.dk/?materialer=halm', 'https://materialepyramiden.dk/?materialer=xps', 'https://materialepyramiden.dk/?materialer=beton-c30-37', 'https://materialepyramiden.dk/?materialer=test-trae']

# %%
# DOWNLOAD ALL MATERIAL FILES

for i in range(len(links)):
    name = links[i].split("=")[-1]
    

    url = links[i]
    print(f"downloading {name} from {url}")
    ua = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'
    response  = requests.get(url, headers={"User-Agent": ua})
    if response.status_code == 200:
        with open(f"./materialer/{name}.html","wb") as file:
            file.write(response.content)
            file.close()
    else:
        print("Bad response code :", response.status_code, url)
    

print("Done")
# Out:
# downloading pandeplade from https://materialepyramiden.dk/?materialer=pandeplade
# downloading maling-mat from https://materialepyramiden.dk/?materialer=maling-mat
# downloading betontagsten from https://materialepyramiden.dk/?materialer=betontagsten
# downloading gulvparket from https://materialepyramiden.dk/?materialer=gulvparket
# downloading mdf from https://materialepyramiden.dk/?materialer=mdf
# downloading poroton-tegl from https://materialepyramiden.dk/?materialer=poroton-tegl
# downloading grantrae from https://materialepyramiden.dk/?materialer=grantrae
# downloading egetrae from https://materialepyramiden.dk/?materialer=egetrae
# downloading modificeret-trae from https://materialepyramiden.dk/?materialer=modificeret-trae
# downloading tegl-roed-dobbeltbraendt from https://materialepyramiden.dk/?materialer=tegl-roed-dobbeltbraendt
# downloading tegl-roed-enkeltbraendt from https://materialepyramiden.dk/?materialer=tegl-roed-enkeltbraendt
# downloading beton-c20-25 from https://materialepyramiden.dk/?materialer=beton-c20-25
# downloading aluvindue from https://materialepyramiden.dk/?materialer=aluvindue
# downloading traevindue from https://materialepyramiden.dk/?materialer=traevindue
# downloading trae-alu-vindue from https://materialepyramiden.dk/?materialer=trae-alu-vindue
# downloading fibercement-plader-18-trae from https://materialepyramiden.dk/?materialer=fibercement-plader-18-trae
# downloading kalkpuds-interioert from https://materialepyramiden.dk/?materialer=kalkpuds-interioert
# downloading zink from https://materialepyramiden.dk/?materialer=zink
# downloading vinyl-gulv-pvc from https://materialepyramiden.dk/?materialer=vinyl-gulv-pvc
# downloading undertag from https://materialepyramiden.dk/?materialer=undertag
# downloading traefiberplade from https://materialepyramiden.dk/?materialer=traefiberplade
# downloading teglsten-tag from https://materialepyramiden.dk/?materialer=teglsten-tag
# downloading tagpap from https://materialepyramiden.dk/?materialer=tagpap
# downloading staal-galvaniseret from https://materialepyramiden.dk/?materialer=staal-galvaniseret
# downloading skifer from https://materialepyramiden.dk/?materialer=skifer
# downloading puds-eksterioert from https://materialepyramiden.dk/?materialer=puds-eksterioert
# downloading gipsplade from https://materialepyramiden.dk/?materialer=gipsplade
# downloading linolieum from https://materialepyramiden.dk/?materialer=linolieum
# downloading lerpuds from https://materialepyramiden.dk/?materialer=lerpuds
# downloading krydslamineret-trae-clt from https://materialepyramiden.dk/?materialer=krydslamineret-trae-clt
# downloading kobber from https://materialepyramiden.dk/?materialer=kobber
# downloading klinker-stentoej from https://materialepyramiden.dk/?materialer=klinker-stentoej
# downloading folier-pe from https://materialepyramiden.dk/?materialer=folier-pe
# downloading folier-epdm from https://materialepyramiden.dk/?materialer=folier-epdm
# downloading fliser-keramik from https://materialepyramiden.dk/?materialer=fliser-keramik
# downloading fibercementplader from https://materialepyramiden.dk/?materialer=fibercementplader
# downloading fermacell-gypsum-fibreboard from https://materialepyramiden.dk/?materialer=fermacell-gypsum-fibreboard
# downloading aluminum-plade from https://materialepyramiden.dk/?materialer=aluminum-plade
# downloading stenuld from https://materialepyramiden.dk/?materialer=stenuld
# downloading pur from https://materialepyramiden.dk/?materialer=pur
# downloading eps-skumplast-hvid from https://materialepyramiden.dk/?materialer=eps-skumplast-hvid
# downloading perlite-ekspanderet from https://materialepyramiden.dk/?materialer=perlite-ekspanderet
# downloading pir from https://materialepyramiden.dk/?materialer=pir
# downloading papiruld from https://materialepyramiden.dk/?materialer=papiruld
# downloading hamp from https://materialepyramiden.dk/?materialer=hamp
# downloading glasuld from https://materialepyramiden.dk/?materialer=glasuld
# downloading glasskum from https://materialepyramiden.dk/?materialer=glasskum
# downloading window-glass-three-3-lags-glas from https://materialepyramiden.dk/?materialer=window-glass-three-3-lags-glas
# downloading window-glass-single-1-lags-glas-2 from https://materialepyramiden.dk/?materialer=window-glass-single-1-lags-glas-2
# downloading plywood-krydsfiner from https://materialepyramiden.dk/?materialer=plywood-krydsfiner
# downloading lerbaserede-mursten-braendte from https://materialepyramiden.dk/?materialer=lerbaserede-mursten-braendte
# downloading kalksandsten from https://materialepyramiden.dk/?materialer=kalksandsten
# downloading genbrugte-mursten-2 from https://materialepyramiden.dk/?materialer=genbrugte-mursten-2
# downloading gasbeton-2 from https://materialepyramiden.dk/?materialer=gasbeton-2
# downloading ceb-compressed-earth-brick-ubraendte-lersten from https://materialepyramiden.dk/?materialer=ceb-compressed-earth-brick-ubraendte-lersten
# downloading rammed-earth-stampede-lervaegge from https://materialepyramiden.dk/?materialer=rammed-earth-stampede-lervaegge
# downloading structural-steel-konstruktionsstaal from https://materialepyramiden.dk/?materialer=structural-steel-konstruktionsstaal
# downloading limtrae from https://materialepyramiden.dk/?materialer=limtrae
# downloading letbetonelementer from https://materialepyramiden.dk/?materialer=letbetonelementer
# downloading traefiberisolering from https://materialepyramiden.dk/?materialer=traefiberisolering
# downloading halm from https://materialepyramiden.dk/?materialer=halm
# downloading xps from https://materialepyramiden.dk/?materialer=xps
# downloading beton-c30-37 from https://materialepyramiden.dk/?materialer=beton-c30-37
# downloading test-trae from https://materialepyramiden.dk/?materialer=test-trae
# Done

# %%
# import OS module

import os
from tkinter.tix import DirList
import sqlite3
 
# Get the list of all files and directories
path = "./materialer/"
dir_list = os.listdir(path)
sqliteConnection = sqlite3.connect('./dataBase/materialDB_dev.db')

cursor = sqliteConnection.cursor()
tableName = "materials"

query = f"DROP TABLE {tableName}"
#cursor.execute(query)

query = f"""CREATE TABLE IF NOT EXISTS {tableName}(
    name	TEXT NOT NULL UNIQUE,
    category TEXT NOT NULL,
    density NUMERIC NOT NULL,
    GWP NUMERIC NOT NULL,
    ODB NUMERIC NOT NULL,
    POCP NUMERIC NOT NULL,
    EP NUMERIC NOT NULL,
    AP NUMERIC NOT NULL,
	PRIMARY KEY("name")
);"""
cursor.execute(query)


cloumnList = "name,category,density,GWP,ODB,POCP,EP,AP"

#for i in range(len(dir_list)):
runLen = len(dir_list)
#runLen = 1
for i in range(runLen):
    filepath = f"{path}{dir_list[i]}"
    print(f"opening {filepath}")
    with open(filepath, "r",encoding='utf8') as file:
        soup = BeautifulSoup(file, "html")

        name = soup.find( class_ = "single-title single-text c1" ).find(class_ = "en").text
        print(f"found name {name}")

        density = ""
        insulation = ""
        cat = ""
        GWP = ""
        ODP = ""
        POCP  = ""
        EP = ""
        AP = ""



        #table = soup.find('table',class_ = "single-table")
        rows = soup.find_all('tr', class_ = 'tr-line')
        print(len(rows))

        
        for row in rows:
            #print(row)
            #print("   ")
            if(row.find(class_ = 'en')):
                if(row.find(class_ = 'en').text == "Density:"):
                    density = row.find(class_ = 't-text t-number t4').text.split(" ")[0]
            
            if(row.find(class_ = 'en')):
                if(row.find(class_ = 'en').text == "Materialgroup:"):
                    cat = row.find(class_ = 't-text t-number t4').text
            
            if(row.find(class_ = 't-text t1')):
                if(row.find(class_ = 't-text t1').text == "Global Warming Potential [GWP]"):
                    if(row.find(class_ = 't-text t3').text.split("/")[-1] == "m3"):
                        GWP = row.find(class_ = 't-text t-number t2').text

            if(row.find(class_ = 't-text t1')):
                if(row.find(class_ = 't-text t1').text == "Ozone Depletion Potential [ODP]"):
                    if(row.find(class_ = 't-text t3').text.split("/")[-1] == "m3"):
                        ODP = row.find(class_ = 't-text t-number t2').text

            if(row.find(class_ = 't-text t1')):
                if(row.find(class_ = 't-text t1').text == "Photochemical Ozone Depletion Potential [POCP]"):
                    if(row.find(class_ = 't-text t3').text.split("/")[-1] == "m3"):
                        POCP = row.find(class_ = 't-text t-number t2').text

            if(row.find(class_ = 't-text t1')):
                if(row.find(class_ = 't-text t1').text == "Eutrophication Potential [EP]"):
                    if(row.find(class_ = 't-text t3').text.split("/")[-1] == "m3"):
                        EP = row.find(class_ = 't-text t-number t2').text
       
            if(row.find(class_ = 't-text t1')):
                if(row.find(class_ = 't-text t1').text == "Acidification Potential [AP]"):
                    if(row.find(class_ = 't-text t3').text.split("/")[-1] == "m3"):
                        AP = row.find(class_ = 't-text t-number t2').text



            #print("   ")


        print(f"name:{name} , category:{cat}, density:{density}, GWP:{GWP}, ODP:{ODP},POCP:{POCP},EP:{EP},AP:{AP}" )
        
        query = f"""INSERT OR REPLACE INTO {tableName} ({cloumnList})
                    VALUES ('{name}' , '{cat}' , {density} , '{GWP}','{ODP}','{POCP}','{EP}','{AP}');"""
        
        print(query)
        cursor.execute(query)


        

        

        
#result = cursor.fetchall()
print('SQLite Version is {}'.format(result))
sqliteConnection.commit()
cursor.close()
# Out:
# opening ./materialer/aluminum-plade.html
# found name Aluminium sheet
# 24
# name:Aluminium sheet , category:metal, density:2700.00, GWP:2.82E+4, ODP:1.19E-1,POCP:5.41E+3,EP:6.42E+3,AP:8.75E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Aluminium sheet' , 'metal' , 2700.00 , '2.82E+4','1.19E-1','5.41E+3','6.42E+3','8.75E+4');
# opening ./materialer/aluvindue.html
# found name Aluminium frame window
# 24
# name:Aluminium frame window , category:komponenter, density:323.74, GWP:1.17E+3, ODP:1.09E+1,POCP:1.68E+1,EP:5.06E+2,AP:5.53E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Aluminium frame window' , 'komponenter' , 323.74 , '1.17E+3','1.09E+1','1.68E+1','5.06E+2','5.53E+3');
# opening ./materialer/beton-c20-25.html
# found name Concrete C20/25
# 24
# name:Concrete C20/25 , category:mineralsk, density:2212.00, GWP:2.29E+2, ODP:2.65E+3,POCP:1.07E+1,EP:1.15E+2,AP:3.70E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Concrete C20/25' , 'mineralsk' , 2212.00 , '2.29E+2','2.65E+3','1.07E+1','1.15E+2','3.70E+2');
# opening ./materialer/beton-c30-37.html
# found name Concrete C30/37
# 24
# name:Concrete C30/37 , category:mineralsk, density:2255.00, GWP:2.88E+2, ODP:3.35E+3,POCP:1.64E+1,EP:1.41E+2,AP:4.43E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Concrete C30/37' , 'mineralsk' , 2255.00 , '2.88E+2','3.35E+3','1.64E+1','1.41E+2','4.43E+2');
# opening ./materialer/betontagsten.html
# found name Concrete roof tiles
# 24
# name:Concrete roof tiles , category:mineralsk, density:1224.57, GWP:3.66E+2, ODP:2.56E+2,POCP:1.20E-1,EP:7.73E+1,AP:1.21E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Concrete roof tiles' , 'mineralsk' , 1224.57 , '3.66E+2','2.56E+2','1.20E-1','7.73E+1','1.21E+3');
# opening ./materialer/ceb-compressed-earth-brick-ubraendte-lersten.html
# found name Unfired clay brick
# 24
# name:Unfired clay brick , category:mineralsk, density:2400.00, GWP:9.36E+1, ODP:4.22E-4,POCP:7.41E+0,EP:9.59E+0,AP:5.57E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Unfired clay brick' , 'mineralsk' , 2400.00 , '9.36E+1','4.22E-4','7.41E+0','9.59E+0','5.57E+1');
# opening ./materialer/egetrae.html
# found name Oak tree
# 24
# name:Oak tree , category:trae, density:710.00, GWP:-1.06E+3, ODP:3.51E-3,POCP:3.90E+2,EP:8.28E+1,AP:3.59E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Oak tree' , 'trae' , 710.00 , '-1.06E+3','3.51E-3','3.90E+2','8.28E+1','3.59E+2');
# opening ./materialer/eps-skumplast-hvid.html
# found name EPS insulation Graphite 80
# 24
# name:EPS insulation Graphite 80 , category:kunststof, density:16.00, GWP:4.35E+1, ODP:2.81E+0,POCP:3.32E+2,EP:1.01E+1,AP:1.10E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('EPS insulation Graphite 80' , 'kunststof' , 16.00 , '4.35E+1','2.81E+0','3.32E+2','1.01E+1','1.10E+2');
# opening ./materialer/fermacell-gypsum-fibreboard.html
# found name Gypsum fibre board (paper)
# 24
# name:Gypsum fibre board (paper) , category:mineralsk, density:1180.00, GWP:9.12E+1, ODP:2.36E+0,POCP:5.40E+0,EP:2.39E+1,AP:1.39E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Gypsum fibre board (paper)' , 'mineralsk' , 1180.00 , '9.12E+1','2.36E+0','5.40E+0','2.39E+1','1.39E+2');
# opening ./materialer/fibercement-plader-18-trae.html
# found name Cement-bonded particle board
# 24
# name:Cement-bonded particle board , category:biobaseret, density:1200.00, GWP:1.69E+3, ODP:1.59E-2,POCP:1.61E+2,EP:2.69E+2,AP:1.62E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Cement-bonded particle board' , 'biobaseret' , 1200.00 , '1.69E+3','1.59E-2','1.61E+2','2.69E+2','1.62E+3');
# opening ./materialer/fibercementplader.html
# found name Fibre cement boards
# 24
# name:Fibre cement boards , category:mineralsk, density:1300.00, GWP:6.99E+2, ODP:1.53E+0,POCP:3.14E+2,EP:2.11E+2,AP:1.40E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Fibre cement boards' , 'mineralsk' , 1300.00 , '6.99E+2','1.53E+0','3.14E+2','2.11E+2','1.40E+3');
# opening ./materialer/fliser-keramik.html
# found name Ceramic tiles
# 24
# name:Ceramic tiles , category:mineralsk, density:2486.67, GWP:1.73E+3, ODP:7.54E+1,POCP:2.81E+2,EP:3.59E+2,AP:3.23E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Ceramic tiles' , 'mineralsk' , 2486.67 , '1.73E+3','7.54E+1','2.81E+2','3.59E+2','3.23E+3');
# opening ./materialer/folier-epdm.html
# found name EPDM foil
# 24
# name:EPDM foil , category:kunststof, density:1333.33, GWP:5.73E+3, ODP:3.46E-2,POCP:8.41E+2,EP:8.00E+2,AP:5.52E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('EPDM foil' , 'kunststof' , 1333.33 , '5.73E+3','3.46E-2','8.41E+2','8.00E+2','5.52E+3');
# opening ./materialer/folier-pe.html
# found name PE film (vapour barrier)
# 24
# name:PE film (vapour barrier) , category:kunststof, density:133.33, GWP:2.66E+2, ODP:2.55E-3,POCP:1.97E+2,EP:8.10E+1,AP:3.47E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('PE film (vapour barrier)' , 'kunststof' , 133.33 , '2.66E+2','2.55E-3','1.97E+2','8.10E+1','3.47E+3');
# opening ./materialer/gasbeton-2.html
# found name Aerated concrete blocks
# 24
# name:Aerated concrete blocks , category:mineralsk, density:375.00, GWP:1.80E+2, ODP:2.55E+0,POCP:1.96E+1,EP:2.80E+1,AP:2.17E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Aerated concrete blocks' , 'mineralsk' , 375.00 , '1.80E+2','2.55E+0','1.96E+1','2.80E+1','2.17E+2');
# opening ./materialer/genbrugte-mursten-2.html
# found name Reused brick
# 24
# name:Reused brick , category:mineralsk, density:1800.00, GWP:4.86E+0, ODP:2.41E+0,POCP:-1.35E+1,EP:2.43E+1,AP:1.11E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Reused brick' , 'mineralsk' , 1800.00 , '4.86E+0','2.41E+0','-1.35E+1','2.43E+1','1.11E+2');
# opening ./materialer/gipsplade.html
# found name Gypsum board
# 24
# name:Gypsum board , category:mineralsk, density:800.00, GWP:1.70E+2, ODP:1.83E+1,POCP:3.09E+1,EP:6.70E+1,AP:2.85E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Gypsum board' , 'mineralsk' , 800.00 , '1.70E+2','1.83E+1','3.09E+1','6.70E+1','2.85E+2');
# opening ./materialer/glasskum.html
# found name Foam glass
# 24
# name:Foam glass , category:mineralsk, density:165.00, GWP:2.44E+2, ODP:3.84E+0,POCP:4.09E+1,EP:6.42E+1,AP:5.23E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Foam glass' , 'mineralsk' , 165.00 , '2.44E+2','3.84E+0','4.09E+1','6.42E+1','5.23E+2');
# opening ./materialer/glasuld.html
# found name Glass wool
# 24
# name:Glass wool , category:mineralsk, density:16.41, GWP:1.28E+1, ODP:1.15E+3,POCP:7.35E+0,EP:4.11E+1,AP:1.21E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Glass wool' , 'mineralsk' , 16.41 , '1.28E+1','1.15E+3','7.35E+0','4.11E+1','1.21E+2');
# opening ./materialer/grantrae.html
# found name Spruce
# 24
# name:Spruce , category:trae, density:460.00, GWP:-7.78E+2, ODP:1.01E-2,POCP:9.83E+0,EP:1.91E+1,AP:7.99E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Spruce' , 'trae' , 460.00 , '-7.78E+2','1.01E-2','9.83E+0','1.91E+1','7.99E+1');
# opening ./materialer/gulvparket.html
# found name Parquet floor, 14 mm
# 24
# name:Parquet floor, 14 mm , category:trae, density:564.29, GWP:-5.35E+2, ODP:4.75E+4,POCP:2.66E+2,EP:4.76E+2,AP:1.80E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Parquet floor, 14 mm' , 'trae' , 564.29 , '-5.35E+2','4.75E+4','2.66E+2','4.76E+2','1.80E+3');
# opening ./materialer/halm.html
# found name Straw
# 24
# name:Straw , category:biobaseret, density:100.00, GWP:-1.28E+2, ODP:3.22E+2,POCP:2.23E+0,EP:1.01E+2,AP:9.32E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Straw' , 'biobaseret' , 100.00 , '-1.28E+2','3.22E+2','2.23E+0','1.01E+2','9.32E+1');
# opening ./materialer/hamp.html
# found name Hemp fleece / PE
# 24
# name:Hemp fleece / PE , category:biobaseret, density:38.00, GWP:1.92E+1, ODP:1.62E-3,POCP:1.08E+1,EP:6.64E+1,AP:1.30E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Hemp fleece / PE' , 'biobaseret' , 38.00 , '1.92E+1','1.62E-3','1.08E+1','6.64E+1','1.30E+2');
# opening ./materialer/kalkpuds-interioert.html
# found name Lime render
# 24
# name:Lime render , category:mineralsk, density:900.00, GWP:1.91E+2, ODP:1.03E-3,POCP:-9.04E+0,EP:3.17E+1,AP:1.19E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Lime render' , 'mineralsk' , 900.00 , '1.91E+2','1.03E-3','-9.04E+0','3.17E+1','1.19E+2');
# opening ./materialer/kalksandsten.html
# found name Lime sandstone
# 24
# name:Lime sandstone , category:mineralsk, density:1800.00, GWP:2.45E+2, ODP:2.77E+0,POCP:4.30E+0,EP:3.08E+1,AP:1.61E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Lime sandstone' , 'mineralsk' , 1800.00 , '2.45E+2','2.77E+0','4.30E+0','3.08E+1','1.61E+2');
# opening ./materialer/klinker-stentoej.html
# found name Clinker – stoneware
# 24
# name:Clinker – stoneware , category:mineralsk, density:2000.00, GWP:6.18E+2, ODP:4.96E-3,POCP:3.26E+1,EP:1.19E+2,AP:6.14E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Clinker – stoneware' , 'mineralsk' , 2000.00 , '6.18E+2','4.96E-3','3.26E+1','1.19E+2','6.14E+2');
# opening ./materialer/kobber.html
# found name Copper sheet
# 24
# name:Copper sheet , category:metal, density:8180.00, GWP:1.24E+4, ODP:1.87E+1,POCP:1.65E+3,EP:3.13E+3,AP:3.07E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Copper sheet' , 'metal' , 8180.00 , '1.24E+4','1.87E+1','1.65E+3','3.13E+3','3.07E+4');
# opening ./materialer/krydslamineret-trae-clt.html
# found name Cross-laminated-timber CLT
# 24
# name:Cross-laminated-timber CLT , category:trae, density:470.00, GWP:-6.64E+2, ODP:4.25E+3,POCP:3.72E+1,EP:2.21E+2,AP:3.28E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Cross-laminated-timber CLT' , 'trae' , 470.00 , '-6.64E+2','4.25E+3','3.72E+1','2.21E+2','3.28E+2');
# opening ./materialer/lerbaserede-mursten-braendte.html
# found name Fired clay brick
# 24
# name:Fired clay brick , category:mineralsk, density:1800.00, GWP:5.28E+2, ODP:3.04E-3,POCP:7.99E+1,EP:8.39E+1,AP:4.52E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Fired clay brick' , 'mineralsk' , 1800.00 , '5.28E+2','3.04E-3','7.99E+1','8.39E+1','4.52E+2');
# opening ./materialer/lerpuds.html
# found name Clay plaster
# 24
# name:Clay plaster , category:mineralsk, density:900.00, GWP:9.32E+1, ODP:6.77E-3,POCP:-3.33E+0,EP:3.20E+1,AP:1.38E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Clay plaster' , 'mineralsk' , 900.00 , '9.32E+1','6.77E-3','-3.33E+0','3.20E+1','1.38E+2');
# opening ./materialer/letbetonelementer.html
# found name Lightweight concrete elements
# 24
# name:Lightweight concrete elements , category:mineralsk, density:900.00, GWP:2.02E+2, ODP:1.30E+2,POCP:2.92E+1,EP:4.08E+1,AP:2.99E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Lightweight concrete elements' , 'mineralsk' , 900.00 , '2.02E+2','1.30E+2','2.92E+1','4.08E+1','2.99E+2');
# opening ./materialer/limtrae.html
# found name Glulam
# 24
# name:Glulam , category:trae, density:500.00, GWP:-6.10E+2, ODP:1.41E+4,POCP:3.03E+1,EP:1.82E+2,AP:5.55E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Glulam' , 'trae' , 500.00 , '-6.10E+2','1.41E+4','3.03E+1','1.82E+2','5.55E+2');
# opening ./materialer/linolieum.html
# found name Linoleum
# 24
# name:Linoleum , category:biobaseret, density:1200.00, GWP:8.35E+1, ODP:5.35E+3,POCP:5.05E+2,EP:2.88E+3,AP:1.20E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Linoleum' , 'biobaseret' , 1200.00 , '8.35E+1','5.35E+3','5.05E+2','2.88E+3','1.20E+4');
# opening ./materialer/maling-mat.html
# found name Paint, matte
# 24
# name:Paint, matte , category:andet, density:1400.00, GWP:2.85E+3, ODP:3.25E+5,POCP:1.58E+3,EP:2.49E+3,AP:1.91E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Paint, matte' , 'andet' , 1400.00 , '2.85E+3','3.25E+5','1.58E+3','2.49E+3','1.91E+4');
# opening ./materialer/mdf.html
# found name MDF
# 24
# name:MDF , category:trae, density:720.00, GWP:-6.69E+2, ODP:5.80E+0,POCP:3.78E+2,EP:4.84E+2,AP:1.28E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('MDF' , 'trae' , 720.00 , '-6.69E+2','5.80E+0','3.78E+2','4.84E+2','1.28E+3');
# opening ./materialer/modificeret-trae.html
# found name Modified wood
# 24
# name:Modified wood , category:trae, density:436.80, GWP:-5.19E+2, ODP:1.97E+4,POCP:7.68E+1,EP:2.84E+2,AP:9.10E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Modified wood' , 'trae' , 436.80 , '-5.19E+2','1.97E+4','7.68E+1','2.84E+2','9.10E+2');
# opening ./materialer/pandeplade.html
# found name Roof panel (steel)
# 24
# name:Roof panel (steel) , category:metal, density:9700.00, GWP:2.66E+4, ODP:7.49E+2,POCP:5.86E+3,EP:6.60E+3,AP:6.02E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Roof panel (steel)' , 'metal' , 9700.00 , '2.66E+4','7.49E+2','5.86E+3','6.60E+3','6.02E+4');
# opening ./materialer/papiruld.html
# found name Paper wool
# 24
# name:Paper wool , category:biobaseret, density:40.00, GWP:6.16E+0, ODP:5.36E+2,POCP:1.88E+0,EP:2.17E+1,AP:3.83E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Paper wool' , 'biobaseret' , 40.00 , '6.16E+0','5.36E+2','1.88E+0','2.17E+1','3.83E+1');
# opening ./materialer/perlite-ekspanderet.html
# found name Expanded perlite
# 24
# name:Expanded perlite , category:mineralsk, density:115.00, GWP:6.01E+1, ODP:1.40E-4,POCP:7.81E+0,EP:1.14E+1,AP:6.09E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Expanded perlite' , 'mineralsk' , 115.00 , '6.01E+1','1.40E-4','7.81E+0','1.14E+1','6.09E+1');
# opening ./materialer/pir.html
# found name PIR insulation
# 24
# name:PIR insulation , category:kunststof, density:250.00, GWP:7.81E+2, ODP:1.33E+6,POCP:3.07E+2,EP:2.20E+2,AP:1.44E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('PIR insulation' , 'kunststof' , 250.00 , '7.81E+2','1.33E+6','3.07E+2','2.20E+2','1.44E+3');
# opening ./materialer/plywood-krydsfiner.html
# found name Plywood
# 24
# name:Plywood , category:trae, density:480.00, GWP:-6.49E+2, ODP:5.48E+3,POCP:1.20E+2,EP:8.00E+1,AP:7.20E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Plywood' , 'trae' , 480.00 , '-6.49E+2','5.48E+3','1.20E+2','8.00E+1','7.20E+2');
# opening ./materialer/poroton-tegl.html
# found name Poroton bricks
# 24
# name:Poroton bricks , category:mineralsk, density:575.00, GWP:1.38E+2, ODP:1.46E+0,POCP:1.32E+1,EP:2.12E+1,AP:1.97E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Poroton bricks' , 'mineralsk' , 575.00 , '1.38E+2','1.46E+0','1.32E+1','2.12E+1','1.97E+2');
# opening ./materialer/puds-eksterioert.html
# found name plaster
# 24
# name:plaster , category:mineralsk, density:1550.00, GWP:3.75E+2, ODP:8.12E+2,POCP:4.71E+0,EP:1.32E+2,AP:5.56E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('plaster' , 'mineralsk' , 1550.00 , '3.75E+2','8.12E+2','4.71E+0','1.32E+2','5.56E+2');
# opening ./materialer/pur.html
# found name PUR insulation
# 24
# name:PUR insulation , category:kunststof, density:33.00, GWP:1.23E+2, ODP:1.95E+5,POCP:1.63E+2,EP:4.08E+1,AP:2.55E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('PUR insulation' , 'kunststof' , 33.00 , '1.23E+2','1.95E+5','1.63E+2','4.08E+1','2.55E+2');
# opening ./materialer/rammed-earth-stampede-lervaegge.html
# found name Rammed earth wall
# 24
# name:Rammed earth wall , category:mineralsk, density:2000.00, GWP:9.35E+0, ODP:3.33E-6,POCP:5.32E+0,EP:7.35E+0,AP:3.13E+1
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Rammed earth wall' , 'mineralsk' , 2000.00 , '9.35E+0','3.33E-6','5.32E+0','7.35E+0','3.13E+1');
# opening ./materialer/skifer.html
# found name Slate
# 24
# name:Slate , category:natursten, density:2730.00, GWP:1.37E+3, ODP:2.02E-2,POCP:8.07E+2,EP:1.82E+3,AP:8.00E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Slate' , 'natursten' , 2730.00 , '1.37E+3','2.02E-2','8.07E+2','1.82E+3','8.00E+3');
# opening ./materialer/staal-galvaniseret.html
# found name Galvanised steel
# 24
# name:Galvanised steel , category:metal, density:8000.00, GWP:2.29E+4, ODP:4.30E-2,POCP:6.29E+3,EP:4.59E+3,AP:4.83E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Galvanised steel' , 'metal' , 8000.00 , '2.29E+4','4.30E-2','6.29E+3','4.59E+3','4.83E+4');
# opening ./materialer/stenuld.html
# found name Stone wool
# 24
# name:Stone wool , category:mineralsk, density:46.25, GWP:7.04E+1, ODP:1.02E-3,POCP:1.75E+1,EP:4.52E+1,AP:3.19E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Stone wool' , 'mineralsk' , 46.25 , '7.04E+1','1.02E-3','1.75E+1','4.52E+1','3.19E+2');
# opening ./materialer/structural-steel-konstruktionsstaal.html
# found name Structural steel
# 24
# name:Structural steel , category:metal, density:7850.00, GWP:8.83E+3, ODP:1.54E+4,POCP:3.15E+6,EP:1.72E+6,AP:1.70E+7
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Structural steel' , 'metal' , 7850.00 , '8.83E+3','1.54E+4','3.15E+6','1.72E+6','1.70E+7');
# opening ./materialer/tagpap.html
# found name Roofing felt V60
# 24
# name:Roofing felt V60 , category:mineralsk, density:1000.00, GWP:4.08E+2, ODP:4.25E-3,POCP:1.71E+2,EP:1.30E+2,AP:1.31E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Roofing felt V60' , 'mineralsk' , 1000.00 , '4.08E+2','4.25E-3','1.71E+2','1.30E+2','1.31E+3');
# opening ./materialer/tegl-roed-dobbeltbraendt.html
# found name Brick, red, double-fired
# 24
# name:Brick, red, double-fired , category:mineralsk, density:1800.00, GWP:8.98E+2, ODP:9.11E+2,POCP:1.22E+2,EP:3.89E+2,AP:1.96E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Brick, red, double-fired' , 'mineralsk' , 1800.00 , '8.98E+2','9.11E+2','1.22E+2','3.89E+2','1.96E+3');
# opening ./materialer/tegl-roed-enkeltbraendt.html
# found name Brick, red, single-fired
# 24
# name:Brick, red, single-fired , category:andet, density:1800.00, GWP:5.65E+2, ODP:9.11E+2,POCP:9.34E+1,EP:3.71E+2,AP:1.80E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Brick, red, single-fired' , 'andet' , 1800.00 , '5.65E+2','9.11E+2','9.34E+1','3.71E+2','1.80E+3');
# opening ./materialer/teglsten-tag.html
# found name Brick roof tiles
# 24
# name:Brick roof tiles , category:mineralsk, density:1259.26, GWP:4.20E+2, ODP:3.03E-3,POCP:7.99E+1,EP:6.20E+1,AP:3.26E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Brick roof tiles' , 'mineralsk' , 1259.26 , '4.20E+2','3.03E-3','7.99E+1','6.20E+1','3.26E+2');
# opening ./materialer/test-trae.html
# found name Construction timber
# 24
# name:Construction timber , category:trae, density:456.00, GWP:-6.80E+2, ODP:9.03E+3,POCP:1.94E+1,EP:5.74E+1,AP:2.42E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Construction timber' , 'trae' , 456.00 , '-6.80E+2','9.03E+3','1.94E+1','5.74E+1','2.42E+3');
# opening ./materialer/trae-alu-vindue.html
# found name Wood-Aluminium frame window
# 24
# name:Wood-Aluminium frame window , category:komponenter, density:323.74, GWP:7.63E+2, ODP:6.01E+0,POCP:-9.50E+1,EP:3.72E+2,AP:3.81E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Wood-Aluminium frame window' , 'komponenter' , 323.74 , '7.63E+2','6.01E+0','-9.50E+1','3.72E+2','3.81E+3');
# opening ./materialer/traefiberisolering.html
# found name Wood fibre insulation
# 24
# name:Wood fibre insulation , category:biobaseret, density:157.49, GWP:-1.73E+2, ODP:7.86E+2,POCP:6.77E+1,EP:6.98E+1,AP:3.06E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Wood fibre insulation' , 'biobaseret' , 157.49 , '-1.73E+2','7.86E+2','6.77E+1','6.98E+1','3.06E+2');
# opening ./materialer/traefiberplade.html
# found name Wood fibre board
# 24
# name:Wood fibre board , category:biobaseret, density:160.00, GWP:-1.83E+2, ODP:2.21E-3,POCP:1.82E+1,EP:2.38E+1,AP:1.24E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Wood fibre board' , 'biobaseret' , 160.00 , '-1.83E+2','2.21E-3','1.82E+1','2.38E+1','1.24E+2');
# opening ./materialer/traevindue.html
# found name Wood frame window
# 24
# name:Wood frame window , category:komponenter, density:323.74, GWP:4.74E+2, ODP:2.88E+0,POCP:-1.66E+2,EP:2.81E+2,AP:2.63E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Wood frame window' , 'komponenter' , 323.74 , '4.74E+2','2.88E+0','-1.66E+2','2.81E+2','2.63E+3');
# opening ./materialer/undertag.html
# found name PP roofing membrane
# 24
# name:PP roofing membrane , category:kunststof, density:100.00, GWP:2.71E+2, ODP:1.47E-3,POCP:8.45E+1,EP:8.48E+1,AP:4.89E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('PP roofing membrane' , 'kunststof' , 100.00 , '2.71E+2','1.47E-3','8.45E+1','8.48E+1','4.89E+2');
# opening ./materialer/vinyl-gulv-pvc.html
# found name Vinyl flooring (PVC)
# 24
# name:Vinyl flooring (PVC) , category:kunststof, density:1650.00, GWP:4.10E+3, ODP:3.46E+2,POCP:1.13E+3,EP:1.06E+3,AP:5.52E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Vinyl flooring (PVC)' , 'kunststof' , 1650.00 , '4.10E+3','3.46E+2','1.13E+3','1.06E+3','5.52E+3');
# opening ./materialer/window-glass-single-1-lags-glas-2.html
# found name Glass pane, double-glazed
# 24
# name:Glass pane, double-glazed , category:komponenter, density:151.08, GWP:2.66E+2, ODP:1.37E-3,POCP:6.47E+1,EP:2.09E+2,AP:1.07E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Glass pane, double-glazed' , 'komponenter' , 151.08 , '2.66E+2','1.37E-3','6.47E+1','2.09E+2','1.07E+3');
# opening ./materialer/window-glass-three-3-lags-glas.html
# found name Glass pane, triple-glazed
# 24
# name:Glass pane, triple-glazed , category:komponenter, density:223.02, GWP:4.16E+2, ODP:2.36E-3,POCP:9.76E+1,EP:3.25E+2,AP:1.66E+3
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Glass pane, triple-glazed' , 'komponenter' , 223.02 , '4.16E+2','2.36E-3','9.76E+1','3.25E+2','1.66E+3');
# opening ./materialer/xps.html
# found name XPS insulation
# 24
# name:XPS insulation , category:kunststof, density:32.00, GWP:9.63E+1, ODP:9.54E-4,POCP:4.46E+1,EP:1.67E+1,AP:1.31E+2
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('XPS insulation' , 'kunststof' , 32.00 , '9.63E+1','9.54E-4','4.46E+1','1.67E+1','1.31E+2');
# opening ./materialer/zink.html
# found name Zinc
# 24
# name:Zinc , category:metal, density:7140.00, GWP:1.22E+4, ODP:7.06E+5,POCP:8.78E+2,EP:1.55E+4,AP:8.14E+4
# INSERT OR REPLACE INTO materials (name,category,density,GWP,ODB,POCP,EP,AP)
#                     VALUES ('Zinc' , 'metal' , 7140.00 , '1.22E+4','7.06E+5','8.78E+2','1.55E+4','8.14E+4');
# SQLite Version is []
